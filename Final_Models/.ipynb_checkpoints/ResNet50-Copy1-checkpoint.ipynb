# %%
import nibabel                      as nib
import nibabel.freesurfer.mghformat as mgh
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import tensorflow as tf
tf.random.set_seed(0)
np.random.seed(0)
from tensorflow import keras
from tensorflow.keras import layers

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.5.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
from scipy import ndimage
from sklearn.preprocessing import minmax_scale

def read_mgz_file(filepath):
    """Read and load volume"""
    # Read file
    scan = mgh.load(filepath)
    # Get raw data
    scan = scan.get_fdata()
    return scan

def convertersize(volume):
    """convertersize the volume"""
    min = -1000
    max = 400
    volume[volume < min] = min
    volume[volume > max] = max
    volume = (volume - min) / (max - min)
    volume = volume.astype("float32")
    return volume

def resize_volume(img):
    """Resize across z-axis"""
    # Set the desired depth
    desired_depth = 256
    desired_width = 256
    desired_height = 256
    # Get current depth
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute depth factor
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    # Rotate
    img = ndimage.rotate(img, 270, reshape=False)
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img

def crop_image(img):
    # Find first and last slices that contain parts of the brain
    blank = img[0].sum()
    x = []
    for i in range(len(img)):
        if img[i,:,:].sum() != blank:
            x.append(i)
    y = []
    for i in range(len(img)):
        if img[:,i,:].sum() != blank:
            y.append(i)
    z = []
    for i in range(len(img)):
        if img[:,:,i].sum() != blank:
            z.append(i)
    # Use these to crop the 3D images
    img = np.squeeze(img[min(x):max(x), min(y):max(y), min(z):max(z)])
    
    # Set the desired depth
    desired_depth = 128
    desired_width = 128
    desired_height = 128
    # Get current depth
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute depth factor
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img

def create_patches(img):
    patches=[]
    for i in [0,32,64]:
        for j in [0,32,64]:
            for k in [0,32,64]:
                patch = np.squeeze(img[i:(i+64), j:(j+64), k:(k+64)])
                # [0, 1] normalization
                patch = patch/(patch.max()/1)
                patch = patch - 1
                patch = abs(patch)
                patch = patch/(patch.max()/1)
                patch = abs(patch-1)
                patches.append(patch)
    return patches

def process_scan(path):
    """Read and resize volume"""
    # Read scan
    volume = read_mgz_file(path)
    #  convertersize
    volume = convertersize(volume)
    # Resize width, height and depth
    volume = resize_volume(volume)
    # Crop 3D image
    volume = crop_image(volume)
    # Create patches
    volume = create_patches(volume)
    return volume

# %%
patches = process_scan('Train_CN/OAS30015_MR_d0116.mgz')
fig = plt.figure(figsize=(21, 7))
columns = 9
rows = 3
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.squeeze(patches[i-1][:, :, 32]), cmap="gray")
plt.show()

# %% [markdown]
# ## Reading data

# %%
# Folder "Train_CN" consist of subjects who remained cognitively converters for the whole study.
Train_CN_paths = [
    os.path.join(os.getcwd(), "Train_CN", x)
    for x in os.listdir("Train_CN")
]

# Folder "Val_CN" consist of subjects who remained cognitively converters for the whole study.
Val_CN_paths = [
    os.path.join(os.getcwd(), "Val_CN", x)
    for x in os.listdir("Val_CN")
]

# Folder "Test_CN" consist of subjects who remained cognitively converters for the whole study.
Test_CN_paths = [
    os.path.join(os.getcwd(), "Test_CN", x)
    for x in os.listdir("Test_CN")
]


# Folder "Train_Converters" consist of subjects who converted from CN to MCI > 0.
Train_Converters_paths = [
    os.path.join(os.getcwd(), "Train_Converters", x)
    for x in os.listdir("Train_Converters")
]

# Folder "Val_Converters" consist of subjects who converted from CN to MCI > 0.
Val_Converters_paths = [
    os.path.join(os.getcwd(), "Val_Converters", x)
    for x in os.listdir("Val_Converters")
]

# Folder "Test_Converters" consist of subjects who converted from CN to MCI > 0.
Test_Converters_paths = [
    os.path.join(os.getcwd(), "Test_Converters", x)
    for x in os.listdir("Test_Converters")
]

print("MRI scans for patients remaining CN (Train): " + str(len(Train_CN_paths)))
print("MRI scans for patients remaining CN (Val): " + str(len(Val_CN_paths)))
print("MRI scans for patients remaining CN (Test): " + str(len(Test_CN_paths)))

print("MRI scans for patients converting to AD (Train): " + str(len(Train_Converters_paths)))
print("MRI scans for patients converting to AD (Val): " + str(len(Val_Converters_paths)))
print("MRI scans for patients converting to AD (Test): " + str(len(Test_Converters_paths)))
# Out:
# MRI scans for patients remaining CN (Train): 30
# MRI scans for patients remaining CN (Val): 10
# MRI scans for patients remaining CN (Test): 10
# MRI scans for patients converting to AD (Train): 30
# MRI scans for patients converting to AD (Val): 10
# MRI scans for patients converting to AD (Test): 10

# %%
# Read and process the scans.
# Each scan is resized across height, width, and depth and rescaled.
Train_CN_scans = np.array([process_scan(path) for path in Train_CN_paths])
Val_CN_scans = np.array([process_scan(path) for path in Val_CN_paths])
Test_CN_scans = np.array([process_scan(path) for path in Test_CN_paths])

Train_Converters_scans = np.array([process_scan(path) for path in Train_Converters_paths])
Val_Converters_scans = np.array([process_scan(path) for path in Val_Converters_paths])
Test_Converters_scans = np.array([process_scan(path) for path in Test_Converters_paths])

# %%
# For the converters assign 1, for the CN subjects assign 0.
Train_CN_labels = np.array([0 for _ in range(len(Train_CN_scans))])
Val_CN_labels = np.array([0 for _ in range(len(Val_CN_scans))])
Test_CN_labels = np.array([0 for _ in range(len(Test_CN_scans))])

Train_Converters_labels = np.array([1 for _ in range(len(Train_Converters_scans))])
Val_Converters_labels = np.array([1 for _ in range(len(Val_Converters_scans))])
Test_Converters_labels = np.array([1 for _ in range(len(Test_Converters_scans))])

# %%
for i in range(27): # For all 27 of the patches
    # Read the patches from the processed scans.
    Train_CN_patches = np.array([scan[i,:,:,:] for scan in Train_CN_scans])
    Val_CN_patches = np.array([scan[i,:,:,:] for scan in Val_CN_scans])
    Test_CN_patches = np.array([scan[i,:,:,:] for scan in Test_CN_scans])
    Train_Converters_patches = np.array([scan[i,:,:,:] for scan in Train_Converters_scans])
    Val_Converters_patches = np.array([scan[i,:,:,:] for scan in Val_Converters_scans])
    Test_Converters_patches = np.array([scan[i,:,:,:] for scan in Test_Converters_scans])

    # Create x and y values for train, validation and test sets
    x_train = np.concatenate((Train_CN_patches, Train_Converters_patches), axis=0)
    x_val = np.concatenate((Val_CN_patches, Val_Converters_patches), axis=0)
    x_test = np.concatenate((Test_CN_patches, Test_Converters_patches), axis=0)
    y_train = np.concatenate((Train_CN_labels, Train_Converters_labels), axis=0)
    y_val = np.concatenate((Val_CN_labels, Val_Converters_labels), axis=0)
    y_test = np.concatenate((Test_CN_labels, Test_Converters_labels), axis=0)

    # Convert image data to RGB (3 channels) so ImageNet weights work
    x_train_rgb = np.repeat(x_train[..., np.newaxis], 3, -1)
    x_val_rgb = np.repeat(x_val[..., np.newaxis], 3, -1)
    x_test_rgb = np.repeat(x_test[..., np.newaxis], 3, -1)

    # Define data loaders.
    train_loader = tf.data.Dataset.from_tensor_slices((x_train_rgb, y_train))
    validation_loader = tf.data.Dataset.from_tensor_slices((x_val_rgb, y_val))
    test_loader = tf.data.Dataset.from_tensor_slices((x_test_rgb, y_test))

    batch_size = 20
    train_dataset = (
        train_loader.shuffle(len(x_train_rgb))
        .batch(batch_size)
        .prefetch(1)
    )
    validation_dataset = (
        validation_loader.shuffle(len(x_val_rgb))
        .batch(batch_size)
        .prefetch(1)
    )
    test_dataset = (
        validation_loader.shuffle(len(x_test_rgb))
        .batch(batch_size)
        .prefetch(1)
    )

    # for tensorflow.keras
    from classification_models_3D.tfkeras import Classifiers

    ResNet50, preprocess_input = Classifiers.get('resnet50')
    base_model = ResNet50(input_shape=(64, 64, 64, 3), weights='imagenet')

    x = base_model.output
    x = tf.keras.layers.Dense(1000,activation='relu')(x) 
    x = tf.keras.layers.Dense(500,activation='relu')(x)
    x = tf.keras.layers.Dense(200,activation='relu')(x) 
    x = tf.keras.layers.Dense(1, activation= 'sigmoid')(x)
    model = keras.Model(inputs = base_model.input, outputs = x)

    auc = tf.keras.metrics.AUC()  # instantiate it here to have a shorter handle

    model.compile(
        loss="binary_crossentropy",
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        metrics=["acc", auc],
    )

    # Define callbacks.
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
        str("ResNet50/3d_image_classification"+str(i)+".h5"), save_best_only=True
    )
    early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=100)

    # Train the model, doing validation at the end of each epoch
    epochs = 1000
    model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=epochs,
        shuffle=True,
        verbose=2,
        callbacks=[checkpoint_cb, early_stopping_cb],
    )

    fig, ax = plt.subplots(1, 2, figsize=(20, 3))
    ax = ax.ravel()

    for i, metric in enumerate(["acc", "loss"]):
        ax[i].plot(model.history.history[metric])
        ax[i].plot(model.history.history["val_" + metric])
        ax[i].set_title("Model {}".format(metric))
        ax[i].set_xlabel("epochs")
        ax[i].set_ylabel(metric)
        ax[i].legend(["train", "val"])
# Out:
# Epoch 1/1000
# 3/3 - 26s - loss: 0.6916 - acc: 0.4667 - auc: 0.5506 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# C:\Users\Justin\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/1000
# 3/3 - 1s - loss: 0.6983 - acc: 0.6000 - auc: 0.5333 - val_loss: 0.6936 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 3/1000
# 3/3 - 1s - loss: 0.6854 - acc: 0.5667 - auc: 0.6156 - val_loss: 0.6978 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 4/1000
# 3/3 - 1s - loss: 0.6915 - acc: 0.5000 - auc: 0.5450 - val_loss: 0.7101 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 5/1000
# 3/3 - 1s - loss: 0.6741 - acc: 0.5833 - auc: 0.5989 - val_loss: 0.7098 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 6/1000
# 3/3 - 1s - loss: 0.6815 - acc: 0.5833 - auc: 0.5611 - val_loss: 0.6975 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 7/1000
# 3/3 - 1s - loss: 0.6681 - acc: 0.6000 - auc: 0.5972 - val_loss: 0.7335 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 8/1000
# 3/3 - 1s - loss: 0.6437 - acc: 0.6833 - auc: 0.6561 - val_loss: 0.7652 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 9/1000
# 3/3 - 1s - loss: 0.5940 - acc: 0.7500 - auc: 0.7567 - val_loss: 0.7519 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 10/1000
# 3/3 - 1s - loss: 0.5792 - acc: 0.7333 - auc: 0.7478 - val_loss: 0.8530 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 11/1000
# 3/3 - 1s - loss: 0.6323 - acc: 0.6333 - auc: 0.7039 - val_loss: 0.7525 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 12/1000
# 3/3 - 1s - loss: 0.7090 - acc: 0.5500 - auc: 0.5767 - val_loss: 1.0191 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 13/1000
# 3/3 - 1s - loss: 0.5447 - acc: 0.7500 - auc: 0.8289 - val_loss: 1.0439 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 14/1000
# 3/3 - 1s - loss: 0.5461 - acc: 0.7833 - auc: 0.8622 - val_loss: 0.7306 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 15/1000
# 3/3 - 1s - loss: 0.6235 - acc: 0.6333 - auc: 0.7189 - val_loss: 0.7434 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 16/1000
# 3/3 - 1s - loss: 0.5039 - acc: 0.6833 - auc: 0.8233 - val_loss: 0.7713 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 17/1000
# 3/3 - 1s - loss: 0.5260 - acc: 0.6833 - auc: 0.8461 - val_loss: 0.6957 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 18/1000
# 3/3 - 1s - loss: 0.4441 - acc: 0.8000 - auc: 0.8633 - val_loss: 1.4794 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 19/1000
# 3/3 - 1s - loss: 0.5638 - acc: 0.7333 - auc: 0.7100 - val_loss: 0.7564 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 20/1000
# 3/3 - 1s - loss: 0.6543 - acc: 0.6167 - auc: 0.6650 - val_loss: 0.7558 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 21/1000
# 3/3 - 1s - loss: 0.6040 - acc: 0.6667 - auc: 0.5867 - val_loss: 0.7225 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 22/1000
# 3/3 - 1s - loss: 0.5538 - acc: 0.6833 - auc: 0.7439 - val_loss: 1.8461 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 23/1000
# 3/3 - 1s - loss: 0.5880 - acc: 0.6167 - auc: 0.7317 - val_loss: 2.0043 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 24/1000
# 3/3 - 1s - loss: 0.6304 - acc: 0.6333 - auc: 0.7617 - val_loss: 2.0198 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 25/1000
# 3/3 - 1s - loss: 0.6270 - acc: 0.6333 - auc: 0.7072 - val_loss: 1.6782 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 26/1000
# 3/3 - 1s - loss: 0.6166 - acc: 0.7000 - auc: 0.7089 - val_loss: 1.4729 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 27/1000
# 3/3 - 1s - loss: 0.6683 - acc: 0.6333 - auc: 0.6461 - val_loss: 1.1281 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 28/1000
# 3/3 - 1s - loss: 0.6079 - acc: 0.6500 - auc: 0.6561 - val_loss: 0.7194 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 29/1000
# 3/3 - 1s - loss: 0.5858 - acc: 0.6833 - auc: 0.6917 - val_loss: 0.7209 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 30/1000
# 3/3 - 1s - loss: 0.5975 - acc: 0.7000 - auc: 0.7294 - val_loss: 0.7264 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 31/1000
# 3/3 - 1s - loss: 0.6102 - acc: 0.6833 - auc: 0.7172 - val_loss: 0.7268 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 32/1000
# 3/3 - 1s - loss: 0.5792 - acc: 0.7167 - auc: 0.7622 - val_loss: 0.7286 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 33/1000
# 3/3 - 1s - loss: 0.5030 - acc: 0.8000 - auc: 0.8233 - val_loss: 0.7392 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 34/1000
# 3/3 - 1s - loss: 0.6253 - acc: 0.7167 - auc: 0.7117 - val_loss: 0.7539 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 35/1000
# 3/3 - 1s - loss: 0.7808 - acc: 0.6333 - auc: 0.5422 - val_loss: 0.7762 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 36/1000
# 3/3 - 1s - loss: 0.6379 - acc: 0.6500 - auc: 0.6639 - val_loss: 0.7927 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 37/1000
# 3/3 - 1s - loss: 0.7025 - acc: 0.5667 - auc: 0.5206 - val_loss: 0.7947 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 38/1000
# 3/3 - 1s - loss: 0.6816 - acc: 0.5500 - auc: 0.4094 - val_loss: 0.7935 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 39/1000
# 3/3 - 1s - loss: 0.6987 - acc: 0.5000 - auc: 0.4450 - val_loss: 0.6935 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 40/1000
# 3/3 - 1s - loss: 0.6955 - acc: 0.5000 - auc: 0.4439 - val_loss: 0.6942 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 41/1000
# 3/3 - 1s - loss: 0.6871 - acc: 0.5833 - auc: 0.6728 - val_loss: 0.6953 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 42/1000
# 3/3 - 1s - loss: 0.6858 - acc: 0.6000 - auc: 0.5639 - val_loss: 0.6972 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 43/1000
# 3/3 - 1s - loss: 0.6756 - acc: 0.6167 - auc: 0.6728 - val_loss: 0.7009 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 44/1000
# 3/3 - 1s - loss: 0.6712 - acc: 0.6333 - auc: 0.6250 - val_loss: 0.7085 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 45/1000
# 3/3 - 1s - loss: 0.6680 - acc: 0.6333 - auc: 0.5956 - val_loss: 0.7195 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 46/1000
# 3/3 - 1s - loss: 0.7025 - acc: 0.5333 - auc: 0.5100 - val_loss: 0.7209 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 47/1000
# 3/3 - 1s - loss: 0.6460 - acc: 0.6667 - auc: 0.6428 - val_loss: 0.7244 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 48/1000
# 3/3 - 1s - loss: 0.6760 - acc: 0.6000 - auc: 0.5517 - val_loss: 0.7278 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 49/1000
# 3/3 - 1s - loss: 0.7159 - acc: 0.5167 - auc: 0.5378 - val_loss: 0.7213 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 50/1000
# 3/3 - 1s - loss: 0.6956 - acc: 0.5667 - auc: 0.5344 - val_loss: 0.7141 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 51/1000
# 3/3 - 1s - loss: 0.6816 - acc: 0.6000 - auc: 0.5600 - val_loss: 0.7047 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 52/1000
# 3/3 - 1s - loss: 0.6644 - acc: 0.6167 - auc: 0.6144 - val_loss: 0.7014 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 53/1000
# 3/3 - 1s - loss: 0.6774 - acc: 0.5833 - auc: 0.5500 - val_loss: 0.6998 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 54/1000
# 3/3 - 1s - loss: 0.6706 - acc: 0.6000 - auc: 0.5944 - val_loss: 0.6993 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 55/1000
# 3/3 - 1s - loss: 0.6682 - acc: 0.6000 - auc: 0.5500 - val_loss: 0.6982 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 56/1000
# 3/3 - 1s - loss: 0.6617 - acc: 0.6167 - auc: 0.5717 - val_loss: 0.6974 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 57/1000
# 3/3 - 1s - loss: 0.6674 - acc: 0.5833 - auc: 0.7144 - val_loss: 0.6973 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 58/1000
# 3/3 - 1s - loss: 0.6244 - acc: 0.6833 - auc: 0.6722 - val_loss: 0.6984 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 59/1000
# 3/3 - 1s - loss: 0.6159 - acc: 0.6833 - auc: 0.5756 - val_loss: 0.7005 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 60/1000
# 3/3 - 1s - loss: 0.5843 - acc: 0.7167 - auc: 0.7156 - val_loss: 0.7042 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 61/1000
# 3/3 - 1s - loss: 0.5563 - acc: 0.7333 - auc: 0.7894 - val_loss: 0.7105 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 62/1000
# 3/3 - 1s - loss: 0.5920 - acc: 0.6833 - auc: 0.5983 - val_loss: 0.7243 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 63/1000
# 3/3 - 1s - loss: 0.6026 - acc: 0.6667 - auc: 0.7189 - val_loss: 0.7293 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 64/1000
# 3/3 - 1s - loss: 0.6500 - acc: 0.6333 - auc: 0.6222 - val_loss: 0.7256 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 65/1000
# 3/3 - 1s - loss: 0.8090 - acc: 0.5667 - auc: 0.5839 - val_loss: 0.7203 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 66/1000
# 3/3 - 1s - loss: 0.9170 - acc: 0.4500 - auc: 0.4800 - val_loss: 0.7084 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 67/1000
# 3/3 - 1s - loss: 0.7748 - acc: 0.4333 - auc: 0.4022 - val_loss: 0.6980 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 68/1000
# 3/3 - 1s - loss: 0.7079 - acc: 0.4833 - auc: 0.4222 - val_loss: 0.6941 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 69/1000
# 3/3 - 1s - loss: 0.7132 - acc: 0.4500 - auc: 0.2356 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 70/1000
# 3/3 - 1s - loss: 0.6998 - acc: 0.4500 - auc: 0.4311 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 71/1000
# 3/3 - 1s - loss: 0.6957 - acc: 0.5000 - auc: 0.4650 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 72/1000
# 3/3 - 1s - loss: 0.6932 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 73/1000
# 3/3 - 1s - loss: 0.6938 - acc: 0.5000 - auc: 0.4839 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 74/1000
# 3/3 - 1s - loss: 0.6931 - acc: 0.5000 - auc: 0.4500 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 75/1000
# 3/3 - 1s - loss: 0.6933 - acc: 0.5000 - auc: 0.5467 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 76/1000
# 3/3 - 1s - loss: 0.6936 - acc: 0.5000 - auc: 0.4589 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 77/1000
# 3/3 - 1s - loss: 0.6934 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 78/1000
# 3/3 - 1s - loss: 0.6931 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 79/1000
# 3/3 - 1s - loss: 0.6938 - acc: 0.5000 - auc: 0.4828 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 80/1000
# 3/3 - 1s - loss: 0.6939 - acc: 0.5000 - auc: 0.4833 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 81/1000
# 3/3 - 1s - loss: 0.6932 - acc: 0.5167 - auc: 0.4667 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 82/1000
# 3/3 - 1s - loss: 0.6935 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 83/1000
# 3/3 - 1s - loss: 0.6931 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 84/1000
# 3/3 - 1s - loss: 0.6932 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 85/1000
# 3/3 - 1s - loss: 0.6931 - acc: 0.5000 - auc: 0.5167 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 86/1000
# 3/3 - 1s - loss: 0.6932 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 87/1000
# 3/3 - 1s - loss: 0.6928 - acc: 0.5167 - auc: 0.5167 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 88/1000
# 3/3 - 1s - loss: 0.6928 - acc: 0.5167 - auc: 0.5178 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 89/1000
# 3/3 - 1s - loss: 0.6924 - acc: 0.5500 - auc: 0.5350 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 90/1000
# 3/3 - 1s - loss: 0.6935 - acc: 0.5000 - auc: 0.4922 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 91/1000
# 3/3 - 1s - loss: 0.6928 - acc: 0.5000 - auc: 0.5517 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 92/1000
# 3/3 - 1s - loss: 0.6932 - acc: 0.5000 - auc: 0.4689 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 93/1000
# 3/3 - 1s - loss: 0.6891 - acc: 0.5667 - auc: 0.5956 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 94/1000
# 3/3 - 1s - loss: 0.6906 - acc: 0.5833 - auc: 0.5550 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 95/1000
# 3/3 - 1s - loss: 0.6923 - acc: 0.5333 - auc: 0.5106 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 96/1000
# 3/3 - 1s - loss: 0.6973 - acc: 0.4667 - auc: 0.4756 - val_loss: 0.6934 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 97/1000
# 3/3 - 1s - loss: 0.6946 - acc: 0.5000 - auc: 0.5000 - val_loss: 0.6934 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 98/1000
# 3/3 - 1s - loss: 0.7088 - acc: 0.4667 - auc: 0.4672 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 99/1000
# 3/3 - 1s - loss: 0.6895 - acc: 0.5333 - auc: 0.5317 - val_loss: 0.7068 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 100/1000
# 3/3 - 1s - loss: 0.6972 - acc: 0.4833 - auc: 0.4844 - val_loss: 0.6999 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 101/1000
# 3/3 - 1s - loss: 0.6974 - acc: 0.4667 - auc: 0.4683 - val_loss: 0.6954 - val_acc: 0.5000 - val_auc: 0.5000
# Epoch 1/1000
# 3/3 - 12s - loss: 0.6935 - acc: 0.4833 - auc_1: 0.4500 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 2/1000
# 3/3 - 1s - loss: 0.6911 - acc: 0.5333 - auc_1: 0.5572 - val_loss: 0.6941 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 3/1000
# 3/3 - 1s - loss: 0.6910 - acc: 0.5500 - auc_1: 0.5439 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 4/1000
# 3/3 - 1s - loss: 0.6697 - acc: 0.6667 - auc_1: 0.6611 - val_loss: 0.6939 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 5/1000
# 3/3 - 1s - loss: 0.6624 - acc: 0.6500 - auc_1: 0.6250 - val_loss: 0.7366 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 6/1000
# 3/3 - 1s - loss: 0.6867 - acc: 0.5833 - auc_1: 0.5628 - val_loss: 0.7234 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 7/1000
# 3/3 - 1s - loss: 0.6651 - acc: 0.6333 - auc_1: 0.5983 - val_loss: 0.7246 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 8/1000
# 3/3 - 1s - loss: 0.6254 - acc: 0.6833 - auc_1: 0.6906 - val_loss: 0.7350 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 9/1000
# 3/3 - 1s - loss: 0.6527 - acc: 0.6500 - auc_1: 0.6039 - val_loss: 0.7486 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 10/1000
# 3/3 - 1s - loss: 0.6447 - acc: 0.6500 - auc_1: 0.6311 - val_loss: 0.7028 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 11/1000
# 3/3 - 1s - loss: 0.6798 - acc: 0.6000 - auc_1: 0.6406 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 12/1000
# 3/3 - 1s - loss: 0.6716 - acc: 0.6000 - auc_1: 0.5806 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 13/1000
# 3/3 - 1s - loss: 0.6443 - acc: 0.6500 - auc_1: 0.5722 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 14/1000
# 3/3 - 1s - loss: 0.6661 - acc: 0.5833 - auc_1: 0.6306 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 15/1000
# 3/3 - 1s - loss: 0.6772 - acc: 0.5500 - auc_1: 0.6367 - val_loss: 0.8215 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 16/1000
# 3/3 - 1s - loss: 0.6678 - acc: 0.6167 - auc_1: 0.7022 - val_loss: 0.8540 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 17/1000
# 3/3 - 1s - loss: 0.6609 - acc: 0.5833 - auc_1: 0.6894 - val_loss: 0.8859 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 18/1000
# 3/3 - 1s - loss: 0.5987 - acc: 0.7167 - auc_1: 0.7328 - val_loss: 0.8884 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 19/1000
# 3/3 - 1s - loss: 0.5932 - acc: 0.6833 - auc_1: 0.7661 - val_loss: 1.2049 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 20/1000
# 3/3 - 1s - loss: 0.4714 - acc: 0.7833 - auc_1: 0.8983 - val_loss: 1.6882 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 21/1000
# 3/3 - 1s - loss: 0.5613 - acc: 0.6500 - auc_1: 0.7933 - val_loss: 1.9162 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 22/1000
# 3/3 - 1s - loss: 0.4458 - acc: 0.8000 - auc_1: 0.8844 - val_loss: 1.6637 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 23/1000
# 3/3 - 1s - loss: 0.4716 - acc: 0.7833 - auc_1: 0.8439 - val_loss: 1.1602 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 24/1000
# 3/3 - 1s - loss: 0.3629 - acc: 0.8833 - auc_1: 0.9106 - val_loss: 1.0572 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 25/1000
# 3/3 - 1s - loss: 0.3841 - acc: 0.8167 - auc_1: 0.8928 - val_loss: 0.9435 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 26/1000
# 3/3 - 1s - loss: 0.4744 - acc: 0.8333 - auc_1: 0.8500 - val_loss: 1.0478 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 27/1000
# 3/3 - 1s - loss: 0.3498 - acc: 0.8667 - auc_1: 0.8922 - val_loss: 1.2356 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 28/1000
# 3/3 - 1s - loss: 0.3512 - acc: 0.8500 - auc_1: 0.9244 - val_loss: 1.3253 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 29/1000
# 3/3 - 1s - loss: 0.3340 - acc: 0.8667 - auc_1: 0.9389 - val_loss: 1.4850 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 30/1000
# 3/3 - 1s - loss: 0.2782 - acc: 0.8833 - auc_1: 0.9756 - val_loss: 1.6943 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 31/1000
# 3/3 - 1s - loss: 0.2401 - acc: 0.9333 - auc_1: 0.9689 - val_loss: 2.0554 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 32/1000
# 3/3 - 1s - loss: 0.1213 - acc: 0.9500 - auc_1: 0.9944 - val_loss: 2.4509 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 33/1000
# 3/3 - 1s - loss: 0.3397 - acc: 0.8833 - auc_1: 0.9289 - val_loss: 2.5965 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 34/1000
# 3/3 - 1s - loss: 0.7526 - acc: 0.7667 - auc_1: 0.7511 - val_loss: 2.5371 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 35/1000
# 3/3 - 1s - loss: 0.3744 - acc: 0.8667 - auc_1: 0.9378 - val_loss: 2.6159 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 36/1000
# 3/3 - 1s - loss: 0.2281 - acc: 0.9333 - auc_1: 0.9839 - val_loss: 2.7808 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 37/1000
# 3/3 - 1s - loss: 0.2900 - acc: 0.8667 - auc_1: 0.9844 - val_loss: 2.8647 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 38/1000
# 3/3 - 1s - loss: 0.2045 - acc: 0.9667 - auc_1: 0.9744 - val_loss: 2.8517 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 39/1000
# 3/3 - 1s - loss: 0.2043 - acc: 0.9500 - auc_1: 0.9567 - val_loss: 2.9375 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 40/1000
# 3/3 - 1s - loss: 0.2180 - acc: 0.9333 - auc_1: 0.9356 - val_loss: 3.0480 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 41/1000
# 3/3 - 1s - loss: 0.2012 - acc: 0.9333 - auc_1: 0.9533 - val_loss: 3.1542 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 42/1000
# 3/3 - 1s - loss: 0.3751 - acc: 0.9000 - auc_1: 0.9561 - val_loss: 3.0070 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 43/1000
# 3/3 - 1s - loss: 0.4202 - acc: 0.9000 - auc_1: 0.9328 - val_loss: 2.1257 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 44/1000
# 3/3 - 1s - loss: 0.3054 - acc: 0.9167 - auc_1: 0.9272 - val_loss: 1.4524 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 45/1000
# 3/3 - 1s - loss: 0.3179 - acc: 0.9000 - auc_1: 0.9494 - val_loss: 1.1506 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 46/1000
# 3/3 - 1s - loss: 0.3019 - acc: 0.9333 - auc_1: 0.9672 - val_loss: 1.0620 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 47/1000
# 3/3 - 1s - loss: 0.2487 - acc: 0.9500 - auc_1: 0.9672 - val_loss: 1.1183 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 48/1000
# 3/3 - 1s - loss: 0.3088 - acc: 0.9167 - auc_1: 0.9417 - val_loss: 1.2674 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 49/1000
# 3/3 - 1s - loss: 0.2909 - acc: 0.9167 - auc_1: 0.9450 - val_loss: 1.3444 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 50/1000
# 3/3 - 1s - loss: 0.1929 - acc: 0.9500 - auc_1: 0.9739 - val_loss: 1.4464 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 51/1000
# 3/3 - 1s - loss: 0.2359 - acc: 0.9333 - auc_1: 0.9533 - val_loss: 1.4709 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 52/1000
# 3/3 - 1s - loss: 0.1617 - acc: 0.9500 - auc_1: 0.9883 - val_loss: 1.4528 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 53/1000
# 3/3 - 1s - loss: 0.0756 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 1.5727 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 54/1000
# 3/3 - 1s - loss: 0.0642 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 1.7917 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 55/1000
# 3/3 - 1s - loss: 0.0276 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.1177 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 56/1000
# 3/3 - 1s - loss: 0.0928 - acc: 0.9833 - auc_1: 0.9750 - val_loss: 2.4016 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 57/1000
# 3/3 - 1s - loss: 0.0081 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.5640 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 58/1000
# 3/3 - 1s - loss: 0.0050 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.7231 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 59/1000
# 3/3 - 1s - loss: 0.2151 - acc: 0.9500 - auc_1: 0.9817 - val_loss: 2.9453 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 60/1000
# 3/3 - 1s - loss: 0.3821 - acc: 0.9000 - auc_1: 0.9550 - val_loss: 2.4472 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 61/1000
# 3/3 - 1s - loss: 0.5912 - acc: 0.8333 - auc_1: 0.8778 - val_loss: 2.3933 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 62/1000
# 3/3 - 1s - loss: 0.4557 - acc: 0.8000 - auc_1: 0.8811 - val_loss: 1.8758 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 63/1000
# 3/3 - 1s - loss: 0.4320 - acc: 0.8167 - auc_1: 0.8861 - val_loss: 1.5754 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 64/1000
# 3/3 - 1s - loss: 0.4081 - acc: 0.8167 - auc_1: 0.8483 - val_loss: 1.4493 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 65/1000
# 3/3 - 1s - loss: 0.3294 - acc: 0.8833 - auc_1: 0.8889 - val_loss: 1.4135 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 66/1000
# 3/3 - 1s - loss: 0.3055 - acc: 0.9000 - auc_1: 0.9372 - val_loss: 1.4890 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 67/1000
# 3/3 - 1s - loss: 0.2273 - acc: 0.9333 - auc_1: 0.9750 - val_loss: 1.6599 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 68/1000
# 3/3 - 1s - loss: 0.1856 - acc: 0.9500 - auc_1: 0.9572 - val_loss: 1.8318 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 69/1000
# 3/3 - 1s - loss: 0.1792 - acc: 0.9500 - auc_1: 0.9733 - val_loss: 1.9538 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 70/1000
# 3/3 - 1s - loss: 0.2468 - acc: 0.9167 - auc_1: 0.9428 - val_loss: 1.7874 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 71/1000
# 3/3 - 1s - loss: 0.1682 - acc: 0.9500 - auc_1: 0.9656 - val_loss: 1.6331 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 72/1000
# 3/3 - 1s - loss: 0.1373 - acc: 0.9667 - auc_1: 0.9756 - val_loss: 1.6408 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 73/1000
# 3/3 - 1s - loss: 0.1295 - acc: 0.9500 - auc_1: 0.9956 - val_loss: 1.6507 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 74/1000
# 3/3 - 1s - loss: 0.1159 - acc: 0.9667 - auc_1: 0.9911 - val_loss: 1.7205 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 75/1000
# 3/3 - 1s - loss: 0.1419 - acc: 0.9333 - auc_1: 0.9883 - val_loss: 1.7605 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 76/1000
# 3/3 - 1s - loss: 0.1326 - acc: 0.9500 - auc_1: 0.9872 - val_loss: 1.9230 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 77/1000
# 3/3 - 1s - loss: 0.0425 - acc: 0.9833 - auc_1: 1.0000 - val_loss: 2.1081 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 78/1000
# 3/3 - 1s - loss: 0.0156 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.3603 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 79/1000
# 3/3 - 1s - loss: 0.0174 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.6388 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 80/1000
# 3/3 - 1s - loss: 0.0059 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.9090 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 81/1000
# 3/3 - 1s - loss: 0.0557 - acc: 0.9833 - auc_1: 1.0000 - val_loss: 3.1267 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 82/1000
# 3/3 - 1s - loss: 0.0332 - acc: 0.9833 - auc_1: 1.0000 - val_loss: 3.2732 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 83/1000
# 3/3 - 1s - loss: 0.0831 - acc: 0.9833 - auc_1: 0.9911 - val_loss: 3.2493 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 84/1000
# 3/3 - 1s - loss: 0.0914 - acc: 0.9833 - auc_1: 0.9894 - val_loss: 3.1174 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 85/1000
# 3/3 - 1s - loss: 0.1039 - acc: 0.9500 - auc_1: 0.9944 - val_loss: 2.9769 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 86/1000
# 3/3 - 1s - loss: 0.0299 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 2.9764 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 87/1000
# 3/3 - 1s - loss: 0.0355 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 3.1007 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 88/1000
# 3/3 - 1s - loss: 0.1604 - acc: 0.9667 - auc_1: 0.9828 - val_loss: 3.2839 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 89/1000
# 3/3 - 1s - loss: 0.0173 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 3.4927 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 90/1000
# 3/3 - 1s - loss: 0.0098 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 3.7217 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 91/1000
# 3/3 - 1s - loss: 0.0050 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 3.9489 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 92/1000
# 3/3 - 1s - loss: 0.0070 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 4.1748 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 93/1000
# 3/3 - 1s - loss: 0.0024 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 4.3744 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 94/1000
# 3/3 - 1s - loss: 0.0020 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 4.5565 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 95/1000
# 3/3 - 1s - loss: 0.0020 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 4.7184 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 96/1000
# 3/3 - 1s - loss: 0.0014 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 4.8606 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 97/1000
# 3/3 - 1s - loss: 0.0027 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 4.9961 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 98/1000
# 3/3 - 1s - loss: 0.0012 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 5.1076 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 99/1000
# 3/3 - 1s - loss: 0.0012 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 5.2044 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 100/1000
# 3/3 - 1s - loss: 6.9611e-04 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 5.2873 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 101/1000
# 3/3 - 1s - loss: 6.6520e-04 - acc: 1.0000 - auc_1: 1.0000 - val_loss: 5.3563 - val_acc: 0.5000 - val_auc_1: 0.5000
# Epoch 1/1000
# 3/3 - 12s - loss: 0.6955 - acc: 0.4667 - auc_2: 0.4372 - val_loss: 0.6946 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 2/1000
# 3/3 - 1s - loss: 0.6907 - acc: 0.5333 - auc_2: 0.5500 - val_loss: 0.7028 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 3/1000
# 3/3 - 1s - loss: 0.6898 - acc: 0.5667 - auc_2: 0.5628 - val_loss: 0.6974 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 4/1000
# 3/3 - 1s - loss: 0.6822 - acc: 0.6333 - auc_2: 0.5939 - val_loss: 0.7145 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 5/1000
# 3/3 - 1s - loss: 0.5954 - acc: 0.8000 - auc_2: 0.8272 - val_loss: 0.7333 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 6/1000
# 3/3 - 1s - loss: 0.5656 - acc: 0.7667 - auc_2: 0.7961 - val_loss: 0.8165 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 7/1000
# 3/3 - 1s - loss: 0.7001 - acc: 0.6333 - auc_2: 0.6161 - val_loss: 0.8827 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 8/1000
# 3/3 - 1s - loss: 0.8566 - acc: 0.4500 - auc_2: 0.4672 - val_loss: 0.8400 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 9/1000
# 3/3 - 1s - loss: 0.7554 - acc: 0.4833 - auc_2: 0.4783 - val_loss: 0.7409 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 10/1000
# 3/3 - 1s - loss: 0.6958 - acc: 0.5000 - auc_2: 0.6439 - val_loss: 0.7008 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 11/1000
# 3/3 - 1s - loss: 0.6869 - acc: 0.5500 - auc_2: 0.6256 - val_loss: 0.6938 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 12/1000
# 3/3 - 1s - loss: 0.6726 - acc: 0.8000 - auc_2: 0.7939 - val_loss: 0.6934 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 13/1000
# 3/3 - 1s - loss: 0.6440 - acc: 0.8000 - auc_2: 0.7800 - val_loss: 0.6947 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 14/1000
# 3/3 - 1s - loss: 0.6179 - acc: 0.7833 - auc_2: 0.7817 - val_loss: 0.6983 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 15/1000
# 3/3 - 1s - loss: 0.6707 - acc: 0.6167 - auc_2: 0.6494 - val_loss: 0.7059 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 16/1000
# 3/3 - 1s - loss: 0.6325 - acc: 0.6667 - auc_2: 0.6656 - val_loss: 0.7166 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 17/1000
# 3/3 - 1s - loss: 0.6776 - acc: 0.6333 - auc_2: 0.6144 - val_loss: 0.7304 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 18/1000
# 3/3 - 1s - loss: 0.6254 - acc: 0.6667 - auc_2: 0.7167 - val_loss: 0.7444 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 19/1000
# 3/3 - 1s - loss: 0.6170 - acc: 0.6833 - auc_2: 0.7411 - val_loss: 0.7427 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 20/1000
# 3/3 - 1s - loss: 0.5901 - acc: 0.7167 - auc_2: 0.7611 - val_loss: 0.7578 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 21/1000
# 3/3 - 1s - loss: 0.5313 - acc: 0.7667 - auc_2: 0.8422 - val_loss: 0.8298 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 22/1000
# 3/3 - 1s - loss: 0.5752 - acc: 0.7500 - auc_2: 0.7328 - val_loss: 0.9385 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 23/1000
# 3/3 - 1s - loss: 0.6105 - acc: 0.6833 - auc_2: 0.7106 - val_loss: 1.0571 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 24/1000
# 3/3 - 1s - loss: 0.4831 - acc: 0.7833 - auc_2: 0.8372 - val_loss: 1.1123 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 25/1000
# 3/3 - 1s - loss: 0.4687 - acc: 0.8167 - auc_2: 0.8522 - val_loss: 1.2216 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 26/1000
# 3/3 - 1s - loss: 0.4914 - acc: 0.7500 - auc_2: 0.8561 - val_loss: 1.3858 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 27/1000
# 3/3 - 1s - loss: 0.4981 - acc: 0.7500 - auc_2: 0.8489 - val_loss: 1.0424 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 28/1000
# 3/3 - 1s - loss: 0.5583 - acc: 0.6500 - auc_2: 0.8583 - val_loss: 1.5824 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 29/1000
# 3/3 - 1s - loss: 0.4353 - acc: 0.7167 - auc_2: 0.8961 - val_loss: 1.7077 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 30/1000
# 3/3 - 1s - loss: 0.4084 - acc: 0.8333 - auc_2: 0.9222 - val_loss: 1.8793 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 31/1000
# 3/3 - 1s - loss: 0.4175 - acc: 0.8333 - auc_2: 0.8600 - val_loss: 2.0647 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 32/1000
# 3/3 - 1s - loss: 0.5590 - acc: 0.7167 - auc_2: 0.7383 - val_loss: 2.2186 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 33/1000
# 3/3 - 1s - loss: 0.5786 - acc: 0.6000 - auc_2: 0.7811 - val_loss: 2.3330 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 34/1000
# 3/3 - 1s - loss: 0.8953 - acc: 0.6833 - auc_2: 0.6483 - val_loss: 1.6173 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 35/1000
# 3/3 - 1s - loss: 0.9163 - acc: 0.5167 - auc_2: 0.4822 - val_loss: 1.2046 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 36/1000
# 3/3 - 1s - loss: 0.7007 - acc: 0.5833 - auc_2: 0.5750 - val_loss: 0.6968 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 37/1000
# 3/3 - 1s - loss: 0.6649 - acc: 0.5833 - auc_2: 0.6389 - val_loss: 0.6971 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 38/1000
# 3/3 - 1s - loss: 0.6875 - acc: 0.6333 - auc_2: 0.6594 - val_loss: 0.7013 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 39/1000
# 3/3 - 1s - loss: 0.6741 - acc: 0.6500 - auc_2: 0.6172 - val_loss: 0.7059 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 40/1000
# 3/3 - 1s - loss: 0.6893 - acc: 0.5667 - auc_2: 0.5061 - val_loss: 0.7105 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 41/1000
# 3/3 - 1s - loss: 0.7029 - acc: 0.5000 - auc_2: 0.5272 - val_loss: 0.7093 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 42/1000
# 3/3 - 1s - loss: 0.6686 - acc: 0.6000 - auc_2: 0.6883 - val_loss: 0.6965 - val_acc: 0.5000 - val_auc_2: 0.3650
# Epoch 43/1000
# 3/3 - 1s - loss: 0.6725 - acc: 0.6000 - auc_2: 0.6100 - val_loss: 0.7048 - val_acc: 0.5000 - val_auc_2: 0.3750
# Epoch 44/1000
# 3/3 - 1s - loss: 0.6842 - acc: 0.5500 - auc_2: 0.5589 - val_loss: 0.7251 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 45/1000
# 3/3 - 1s - loss: 0.7155 - acc: 0.4833 - auc_2: 0.4728 - val_loss: 0.7221 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 46/1000
# 3/3 - 1s - loss: 0.6899 - acc: 0.5333 - auc_2: 0.5000 - val_loss: 0.7182 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 47/1000
# 3/3 - 1s - loss: 0.6562 - acc: 0.6667 - auc_2: 0.6600 - val_loss: 0.7193 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 48/1000
# 3/3 - 1s - loss: 0.6706 - acc: 0.6167 - auc_2: 0.5661 - val_loss: 0.7238 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 49/1000
# 3/3 - 1s - loss: 0.6518 - acc: 0.6500 - auc_2: 0.6111 - val_loss: 0.7383 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 50/1000
# 3/3 - 1s - loss: 0.6928 - acc: 0.5500 - auc_2: 0.5789 - val_loss: 0.7484 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 51/1000
# 3/3 - 1s - loss: 0.7074 - acc: 0.5000 - auc_2: 0.5239 - val_loss: 0.7548 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 52/1000
# 3/3 - 1s - loss: 0.6607 - acc: 0.5833 - auc_2: 0.6689 - val_loss: 0.7561 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 53/1000
# 3/3 - 1s - loss: 0.6607 - acc: 0.6000 - auc_2: 0.6400 - val_loss: 0.7583 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 54/1000
# 3/3 - 1s - loss: 0.6128 - acc: 0.6833 - auc_2: 0.7472 - val_loss: 0.7771 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 55/1000
# 3/3 - 1s - loss: 0.6464 - acc: 0.6833 - auc_2: 0.6411 - val_loss: 0.7919 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 56/1000
# 3/3 - 1s - loss: 0.6607 - acc: 0.6333 - auc_2: 0.6450 - val_loss: 0.8178 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 57/1000
# 3/3 - 1s - loss: 0.6292 - acc: 0.6667 - auc_2: 0.6794 - val_loss: 0.8406 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 58/1000
# 3/3 - 1s - loss: 0.6069 - acc: 0.6667 - auc_2: 0.7272 - val_loss: 0.8641 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 59/1000
# 3/3 - 1s - loss: 0.6534 - acc: 0.6833 - auc_2: 0.6600 - val_loss: 0.8720 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 60/1000
# 3/3 - 1s - loss: 0.6496 - acc: 0.6500 - auc_2: 0.6650 - val_loss: 0.8460 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 61/1000
# 3/3 - 1s - loss: 0.5769 - acc: 0.7000 - auc_2: 0.7789 - val_loss: 0.8325 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 62/1000
# 3/3 - 1s - loss: 0.5879 - acc: 0.7167 - auc_2: 0.7433 - val_loss: 0.8348 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 63/1000
# 3/3 - 1s - loss: 0.5485 - acc: 0.7167 - auc_2: 0.7678 - val_loss: 0.8836 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 64/1000
# 3/3 - 1s - loss: 0.4786 - acc: 0.8167 - auc_2: 0.8517 - val_loss: 0.9969 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 65/1000
# 3/3 - 1s - loss: 0.4613 - acc: 0.8167 - auc_2: 0.8117 - val_loss: 1.2131 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 66/1000
# 3/3 - 1s - loss: 0.3853 - acc: 0.8500 - auc_2: 0.8617 - val_loss: 1.5591 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 67/1000
# 3/3 - 1s - loss: 0.4300 - acc: 0.8000 - auc_2: 0.8444 - val_loss: 1.9738 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 68/1000
# 3/3 - 1s - loss: 0.5093 - acc: 0.7333 - auc_2: 0.7794 - val_loss: 2.2578 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 69/1000
# 3/3 - 1s - loss: 0.4789 - acc: 0.7333 - auc_2: 0.8644 - val_loss: 2.5116 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 70/1000
# 3/3 - 1s - loss: 0.6377 - acc: 0.7500 - auc_2: 0.7694 - val_loss: 0.7048 - val_acc: 0.5000 - val_auc_2: 0.3050
# Epoch 71/1000
# 3/3 - 1s - loss: 0.5725 - acc: 0.7500 - auc_2: 0.7722 - val_loss: 1.3355 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 72/1000
# 3/3 - 1s - loss: 0.7528 - acc: 0.6500 - auc_2: 0.6139 - val_loss: 1.2786 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 73/1000
# 3/3 - 1s - loss: 0.7721 - acc: 0.4833 - auc_2: 0.5367 - val_loss: 0.7424 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 74/1000
# 3/3 - 1s - loss: 0.6896 - acc: 0.6333 - auc_2: 0.6128 - val_loss: 0.7302 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 75/1000
# 3/3 - 1s - loss: 0.6652 - acc: 0.6167 - auc_2: 0.6506 - val_loss: 0.7430 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 76/1000
# 3/3 - 1s - loss: 0.6888 - acc: 0.5667 - auc_2: 0.5522 - val_loss: 0.7634 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 77/1000
# 3/3 - 1s - loss: 0.6693 - acc: 0.5667 - auc_2: 0.5622 - val_loss: 0.7821 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 78/1000
# 3/3 - 1s - loss: 0.6539 - acc: 0.6000 - auc_2: 0.5467 - val_loss: 0.8114 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 79/1000
# 3/3 - 1s - loss: 0.6467 - acc: 0.6167 - auc_2: 0.5972 - val_loss: 0.8540 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 80/1000
# 3/3 - 1s - loss: 0.6691 - acc: 0.6000 - auc_2: 0.6283 - val_loss: 0.8845 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 81/1000
# 3/3 - 1s - loss: 0.6397 - acc: 0.6667 - auc_2: 0.6661 - val_loss: 0.6979 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 82/1000
# 3/3 - 1s - loss: 0.6278 - acc: 0.6833 - auc_2: 0.6689 - val_loss: 0.9453 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 83/1000
# 3/3 - 1s - loss: 0.6305 - acc: 0.6833 - auc_2: 0.6389 - val_loss: 0.9189 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 84/1000
# 3/3 - 1s - loss: 0.6298 - acc: 0.6833 - auc_2: 0.6911 - val_loss: 0.9260 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 85/1000
# 3/3 - 1s - loss: 0.5952 - acc: 0.7333 - auc_2: 0.7683 - val_loss: 0.9182 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 86/1000
# 3/3 - 1s - loss: 0.6620 - acc: 0.6167 - auc_2: 0.6506 - val_loss: 0.8701 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 87/1000
# 3/3 - 1s - loss: 0.6533 - acc: 0.6167 - auc_2: 0.5683 - val_loss: 0.8347 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 88/1000
# 3/3 - 1s - loss: 0.6676 - acc: 0.6000 - auc_2: 0.5817 - val_loss: 0.8142 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 89/1000
# 3/3 - 1s - loss: 0.6639 - acc: 0.6000 - auc_2: 0.5461 - val_loss: 0.8054 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 90/1000
# 3/3 - 1s - loss: 0.6624 - acc: 0.6000 - auc_2: 0.4828 - val_loss: 0.8034 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 91/1000
# 3/3 - 1s - loss: 0.6595 - acc: 0.6000 - auc_2: 0.6400 - val_loss: 0.8093 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 92/1000
# 3/3 - 1s - loss: 0.6506 - acc: 0.6167 - auc_2: 0.6594 - val_loss: 0.8223 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 93/1000
# 3/3 - 1s - loss: 0.6702 - acc: 0.5833 - auc_2: 0.6133 - val_loss: 0.8405 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 94/1000
# 3/3 - 1s - loss: 0.6992 - acc: 0.5500 - auc_2: 0.5528 - val_loss: 0.8380 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 95/1000
# 3/3 - 1s - loss: 0.6834 - acc: 0.5500 - auc_2: 0.5811 - val_loss: 0.8293 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 96/1000
# 3/3 - 1s - loss: 0.6718 - acc: 0.5667 - auc_2: 0.5744 - val_loss: 0.8181 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 97/1000
# 3/3 - 1s - loss: 0.7064 - acc: 0.5000 - auc_2: 0.4533 - val_loss: 0.8067 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 98/1000
# 3/3 - 1s - loss: 0.7233 - acc: 0.4667 - auc_2: 0.4722 - val_loss: 0.7540 - val_acc: 0.5000 - val_auc_2: 0.5150
# Epoch 99/1000
# 3/3 - 1s - loss: 0.6998 - acc: 0.5333 - auc_2: 0.5272 - val_loss: 0.6940 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 100/1000
# 3/3 - 1s - loss: 0.6747 - acc: 0.5667 - auc_2: 0.5811 - val_loss: 0.6944 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 101/1000
# 3/3 - 1s - loss: 0.7159 - acc: 0.4833 - auc_2: 0.4933 - val_loss: 0.6943 - val_acc: 0.5000 - val_auc_2: 0.5000
# Epoch 1/1000
# 3/3 - 12s - loss: 0.6971 - acc: 0.4500 - auc_3: 0.3856 - val_loss: 0.6931 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 2/1000
# 3/3 - 1s - loss: 0.6886 - acc: 0.5000 - auc_3: 0.5894 - val_loss: 0.6946 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 3/1000
# 3/3 - 1s - loss: 0.6924 - acc: 0.5333 - auc_3: 0.5506 - val_loss: 0.6949 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 4/1000
# 3/3 - 1s - loss: 0.6939 - acc: 0.4667 - auc_3: 0.4972 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 5/1000
# 3/3 - 1s - loss: 0.6759 - acc: 0.5667 - auc_3: 0.6206 - val_loss: 0.7142 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 6/1000
# 3/3 - 1s - loss: 0.7015 - acc: 0.4833 - auc_3: 0.4589 - val_loss: 0.6996 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 7/1000
# 3/3 - 1s - loss: 0.6974 - acc: 0.5667 - auc_3: 0.4733 - val_loss: 0.6961 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 8/1000
# 3/3 - 1s - loss: 0.6916 - acc: 0.5333 - auc_3: 0.5250 - val_loss: 0.6939 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 9/1000
# 3/3 - 1s - loss: 0.7253 - acc: 0.3833 - auc_3: 0.3178 - val_loss: 0.6935 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 10/1000
# 3/3 - 1s - loss: 0.6915 - acc: 0.5167 - auc_3: 0.4950 - val_loss: 0.6935 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 11/1000
# 3/3 - 1s - loss: 0.6919 - acc: 0.5167 - auc_3: 0.6111 - val_loss: 0.6939 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 12/1000
# 3/3 - 1s - loss: 0.6912 - acc: 0.5167 - auc_3: 0.5928 - val_loss: 0.6948 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 13/1000
# 3/3 - 1s - loss: 0.6902 - acc: 0.5000 - auc_3: 0.5822 - val_loss: 0.6962 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 14/1000
# 3/3 - 1s - loss: 0.6891 - acc: 0.5000 - auc_3: 0.5656 - val_loss: 0.6991 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 15/1000
# 3/3 - 1s - loss: 0.6884 - acc: 0.5000 - auc_3: 0.6189 - val_loss: 0.7024 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 16/1000
# 3/3 - 1s - loss: 0.6828 - acc: 0.6333 - auc_3: 0.6172 - val_loss: 0.7100 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 17/1000
# 3/3 - 1s - loss: 0.6780 - acc: 0.6333 - auc_3: 0.6222 - val_loss: 0.7236 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 18/1000
# 3/3 - 1s - loss: 0.6699 - acc: 0.6500 - auc_3: 0.6106 - val_loss: 0.7396 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 19/1000
# 3/3 - 1s - loss: 0.6887 - acc: 0.6000 - auc_3: 0.5994 - val_loss: 0.7386 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 20/1000
# 3/3 - 1s - loss: 0.6830 - acc: 0.5833 - auc_3: 0.6428 - val_loss: 0.7435 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 21/1000
# 3/3 - 1s - loss: 0.6957 - acc: 0.6000 - auc_3: 0.5000 - val_loss: 0.7441 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 22/1000
# 3/3 - 1s - loss: 0.6608 - acc: 0.6500 - auc_3: 0.6139 - val_loss: 0.7298 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 23/1000
# 3/3 - 1s - loss: 0.6641 - acc: 0.6333 - auc_3: 0.6539 - val_loss: 0.7262 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 24/1000
# 3/3 - 1s - loss: 0.6498 - acc: 0.6500 - auc_3: 0.6822 - val_loss: 0.7302 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 25/1000
# 3/3 - 1s - loss: 0.7378 - acc: 0.4833 - auc_3: 0.4561 - val_loss: 0.7240 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 26/1000
# 3/3 - 1s - loss: 0.7333 - acc: 0.4667 - auc_3: 0.4150 - val_loss: 0.7045 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 27/1000
# 3/3 - 1s - loss: 0.6965 - acc: 0.5333 - auc_3: 0.4922 - val_loss: 0.6953 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 28/1000
# 3/3 - 1s - loss: 0.6911 - acc: 0.5167 - auc_3: 0.5611 - val_loss: 0.6931 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 29/1000
# 3/3 - 1s - loss: 0.6847 - acc: 0.5333 - auc_3: 0.5444 - val_loss: 0.6945 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 30/1000
# 3/3 - 1s - loss: 0.6961 - acc: 0.4833 - auc_3: 0.4911 - val_loss: 0.6949 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 31/1000
# 3/3 - 1s - loss: 0.6971 - acc: 0.4667 - auc_3: 0.4456 - val_loss: 0.7003 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 32/1000
# 3/3 - 1s - loss: 0.7032 - acc: 0.4333 - auc_3: 0.4083 - val_loss: 0.6991 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 33/1000
# 3/3 - 1s - loss: 0.6861 - acc: 0.5333 - auc_3: 0.5689 - val_loss: 0.6987 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 34/1000
# 3/3 - 1s - loss: 0.6886 - acc: 0.4667 - auc_3: 0.4928 - val_loss: 0.6993 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 35/1000
# 3/3 - 1s - loss: 0.6866 - acc: 0.5167 - auc_3: 0.5417 - val_loss: 0.7008 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 36/1000
# 3/3 - 1s - loss: 0.6847 - acc: 0.5667 - auc_3: 0.5700 - val_loss: 0.7037 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 37/1000
# 3/3 - 1s - loss: 0.6782 - acc: 0.6333 - auc_3: 0.6617 - val_loss: 0.7100 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 38/1000
# 3/3 - 1s - loss: 0.6743 - acc: 0.6167 - auc_3: 0.5539 - val_loss: 0.7227 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 39/1000
# 3/3 - 1s - loss: 0.6547 - acc: 0.6500 - auc_3: 0.6267 - val_loss: 0.7496 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 40/1000
# 3/3 - 1s - loss: 0.6672 - acc: 0.5833 - auc_3: 0.6389 - val_loss: 0.8041 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 41/1000
# 3/3 - 1s - loss: 0.6589 - acc: 0.6000 - auc_3: 0.6472 - val_loss: 0.8898 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 42/1000
# 3/3 - 1s - loss: 0.6432 - acc: 0.6333 - auc_3: 0.6083 - val_loss: 1.0182 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 43/1000
# 3/3 - 1s - loss: 0.6669 - acc: 0.6000 - auc_3: 0.6089 - val_loss: 1.1379 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 44/1000
# 3/3 - 1s - loss: 0.6355 - acc: 0.6500 - auc_3: 0.6539 - val_loss: 1.3262 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 45/1000
# 3/3 - 1s - loss: 0.6946 - acc: 0.6000 - auc_3: 0.5817 - val_loss: 1.2912 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 46/1000
# 3/3 - 1s - loss: 0.6649 - acc: 0.6000 - auc_3: 0.5611 - val_loss: 1.2001 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 47/1000
# 3/3 - 1s - loss: 0.6318 - acc: 0.6500 - auc_3: 0.5844 - val_loss: 1.2039 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 48/1000
# 3/3 - 1s - loss: 0.6230 - acc: 0.6333 - auc_3: 0.6456 - val_loss: 1.2701 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 49/1000
# 3/3 - 1s - loss: 0.6025 - acc: 0.6500 - auc_3: 0.6411 - val_loss: 1.3622 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 50/1000
# 3/3 - 1s - loss: 0.6066 - acc: 0.6667 - auc_3: 0.6617 - val_loss: 1.4829 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 51/1000
# 3/3 - 1s - loss: 0.5659 - acc: 0.7000 - auc_3: 0.6422 - val_loss: 1.5483 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 52/1000
# 3/3 - 1s - loss: 0.5831 - acc: 0.6667 - auc_3: 0.5456 - val_loss: 1.6784 - val_acc: 0.4500 - val_auc_3: 0.4500
# Epoch 53/1000
# 3/3 - 1s - loss: 0.6143 - acc: 0.6667 - auc_3: 0.6033 - val_loss: 0.7218 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 54/1000
# 3/3 - 1s - loss: 0.5773 - acc: 0.7000 - auc_3: 0.6678 - val_loss: 0.7197 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 55/1000
# 3/3 - 1s - loss: 0.5394 - acc: 0.7167 - auc_3: 0.6411 - val_loss: 0.7211 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 56/1000
# 3/3 - 1s - loss: 0.6835 - acc: 0.6833 - auc_3: 0.6806 - val_loss: 0.7247 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 57/1000
# 3/3 - 1s - loss: 0.5911 - acc: 0.6833 - auc_3: 0.6172 - val_loss: 0.7324 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 58/1000
# 3/3 - 1s - loss: 0.5685 - acc: 0.7000 - auc_3: 0.5878 - val_loss: 0.7336 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 59/1000
# 3/3 - 1s - loss: 0.6991 - acc: 0.6000 - auc_3: 0.6333 - val_loss: 1.0318 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 60/1000
# 3/3 - 1s - loss: 0.7982 - acc: 0.5167 - auc_3: 0.5333 - val_loss: 0.8797 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 61/1000
# 3/3 - 1s - loss: 0.8152 - acc: 0.4000 - auc_3: 0.4322 - val_loss: 0.7625 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 62/1000
# 3/3 - 1s - loss: 0.6855 - acc: 0.6000 - auc_3: 0.5550 - val_loss: 0.6995 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 63/1000
# 3/3 - 1s - loss: 0.6726 - acc: 0.5833 - auc_3: 0.6506 - val_loss: 0.6974 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 64/1000
# 3/3 - 1s - loss: 0.6814 - acc: 0.5167 - auc_3: 0.6244 - val_loss: 0.6963 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 65/1000
# 3/3 - 1s - loss: 0.6834 - acc: 0.5333 - auc_3: 0.6011 - val_loss: 0.6961 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 66/1000
# 3/3 - 1s - loss: 0.6808 - acc: 0.6333 - auc_3: 0.6100 - val_loss: 0.6964 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 67/1000
# 3/3 - 1s - loss: 0.6801 - acc: 0.6000 - auc_3: 0.6361 - val_loss: 0.6966 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 68/1000
# 3/3 - 1s - loss: 0.6724 - acc: 0.6333 - auc_3: 0.6683 - val_loss: 0.6973 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 69/1000
# 3/3 - 1s - loss: 0.6635 - acc: 0.6500 - auc_3: 0.6756 - val_loss: 0.6984 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 70/1000
# 3/3 - 1s - loss: 0.6494 - acc: 0.6500 - auc_3: 0.6922 - val_loss: 0.7006 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 71/1000
# 3/3 - 1s - loss: 0.6294 - acc: 0.6667 - auc_3: 0.6833 - val_loss: 0.7044 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 72/1000
# 3/3 - 1s - loss: 0.5985 - acc: 0.7000 - auc_3: 0.7489 - val_loss: 0.7095 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 73/1000
# 3/3 - 1s - loss: 0.6038 - acc: 0.6667 - auc_3: 0.7217 - val_loss: 1.5074 - val_acc: 0.4000 - val_auc_3: 0.4000
# Epoch 74/1000
# 3/3 - 1s - loss: 0.5793 - acc: 0.6667 - auc_3: 0.7461 - val_loss: 1.5495 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 75/1000
# 3/3 - 1s - loss: 0.5309 - acc: 0.7167 - auc_3: 0.7206 - val_loss: 1.6967 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 76/1000
# 3/3 - 1s - loss: 0.6237 - acc: 0.6667 - auc_3: 0.6511 - val_loss: 1.6670 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 77/1000
# 3/3 - 1s - loss: 0.6247 - acc: 0.6500 - auc_3: 0.7250 - val_loss: 1.5654 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 78/1000
# 3/3 - 1s - loss: 0.5284 - acc: 0.7000 - auc_3: 0.7978 - val_loss: 1.5955 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 79/1000
# 3/3 - 1s - loss: 0.5720 - acc: 0.7000 - auc_3: 0.7356 - val_loss: 1.5504 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 80/1000
# 3/3 - 1s - loss: 0.5967 - acc: 0.6833 - auc_3: 0.7228 - val_loss: 1.4403 - val_acc: 0.5000 - val_auc_3: 0.5000
# Epoch 81/1000
# 3/3 - 1s - loss: 0.7045 - acc: 0.6167 - auc_3: 0.6706 - val_loss: 1.1657 - val_acc: 0.4000 - val_auc_3: 0.4100
# Epoch 82/1000
# ...
# Epoch 51/1000
# 3/3 - 1s - loss: 0.4838 - acc: 0.8000 - auc_26: 0.8350 - val_loss: 1.9808 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 52/1000
# 3/3 - 1s - loss: 0.4144 - acc: 0.8167 - auc_26: 0.8467 - val_loss: 2.0629 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 53/1000
# 3/3 - 1s - loss: 0.6340 - acc: 0.7500 - auc_26: 0.7578 - val_loss: 1.7575 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 54/1000
# 3/3 - 1s - loss: 0.5003 - acc: 0.7833 - auc_26: 0.8278 - val_loss: 1.5818 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 55/1000
# 3/3 - 1s - loss: 0.5432 - acc: 0.7500 - auc_26: 0.8256 - val_loss: 1.4804 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 56/1000
# 3/3 - 1s - loss: 0.4293 - acc: 0.8333 - auc_26: 0.7939 - val_loss: 1.4417 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 57/1000
# 3/3 - 1s - loss: 0.5223 - acc: 0.7667 - auc_26: 0.7767 - val_loss: 1.3434 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 58/1000
# 3/3 - 1s - loss: 0.5204 - acc: 0.7167 - auc_26: 0.7933 - val_loss: 1.3090 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 59/1000
# 3/3 - 1s - loss: 0.4929 - acc: 0.7667 - auc_26: 0.8294 - val_loss: 1.3110 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 60/1000
# 3/3 - 1s - loss: 0.4892 - acc: 0.8000 - auc_26: 0.7867 - val_loss: 1.3162 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 61/1000
# 3/3 - 1s - loss: 0.6082 - acc: 0.7333 - auc_26: 0.7161 - val_loss: 1.2172 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 62/1000
# 3/3 - 1s - loss: 0.4779 - acc: 0.8000 - auc_26: 0.8522 - val_loss: 1.1465 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 63/1000
# 3/3 - 1s - loss: 0.4590 - acc: 0.8500 - auc_26: 0.8578 - val_loss: 1.1085 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 64/1000
# 3/3 - 1s - loss: 0.4216 - acc: 0.8667 - auc_26: 0.8383 - val_loss: 1.0775 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 65/1000
# 3/3 - 1s - loss: 0.4064 - acc: 0.8333 - auc_26: 0.9167 - val_loss: 1.0602 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 66/1000
# 3/3 - 1s - loss: 0.4390 - acc: 0.8500 - auc_26: 0.8417 - val_loss: 1.0344 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 67/1000
# 3/3 - 1s - loss: 0.3966 - acc: 0.8500 - auc_26: 0.8994 - val_loss: 0.9993 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 68/1000
# 3/3 - 1s - loss: 0.3855 - acc: 0.8500 - auc_26: 0.8511 - val_loss: 1.0838 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 69/1000
# 3/3 - 1s - loss: 0.4045 - acc: 0.8500 - auc_26: 0.8522 - val_loss: 1.0526 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 70/1000
# 3/3 - 1s - loss: 0.5019 - acc: 0.8000 - auc_26: 0.8172 - val_loss: 0.9809 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 71/1000
# 3/3 - 1s - loss: 0.5018 - acc: 0.7833 - auc_26: 0.8211 - val_loss: 0.8491 - val_acc: 0.5000 - val_auc_26: 0.4250
# Epoch 72/1000
# 3/3 - 1s - loss: 0.6285 - acc: 0.7000 - auc_26: 0.7911 - val_loss: 0.8061 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 73/1000
# 3/3 - 1s - loss: 0.5205 - acc: 0.7667 - auc_26: 0.7078 - val_loss: 0.7904 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 74/1000
# 3/3 - 1s - loss: 0.5051 - acc: 0.7833 - auc_26: 0.7639 - val_loss: 0.7819 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 75/1000
# 3/3 - 1s - loss: 0.4766 - acc: 0.8167 - auc_26: 0.8878 - val_loss: 0.7280 - val_acc: 0.5500 - val_auc_26: 0.5500
# Epoch 76/1000
# 3/3 - 1s - loss: 0.4960 - acc: 0.8000 - auc_26: 0.8139 - val_loss: 1.2613 - val_acc: 0.5000 - val_auc_26: 0.6000
# Epoch 77/1000
# 3/3 - 1s - loss: 0.4972 - acc: 0.7667 - auc_26: 0.8350 - val_loss: 0.7325 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 78/1000
# 3/3 - 1s - loss: 0.4490 - acc: 0.8167 - auc_26: 0.8600 - val_loss: 0.7455 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 79/1000
# 3/3 - 1s - loss: 0.4860 - acc: 0.7667 - auc_26: 0.7578 - val_loss: 0.7649 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 80/1000
# 3/3 - 1s - loss: 0.4783 - acc: 0.8333 - auc_26: 0.8256 - val_loss: 0.7841 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 81/1000
# 3/3 - 1s - loss: 0.6140 - acc: 0.7333 - auc_26: 0.8139 - val_loss: 0.8046 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 82/1000
# 3/3 - 1s - loss: 0.5560 - acc: 0.7500 - auc_26: 0.7822 - val_loss: 0.7671 - val_acc: 0.5500 - val_auc_26: 0.5500
# Epoch 83/1000
# 3/3 - 1s - loss: 0.7911 - acc: 0.5333 - auc_26: 0.5061 - val_loss: 0.7065 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 84/1000
# 3/3 - 1s - loss: 0.7596 - acc: 0.5000 - auc_26: 0.5222 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 85/1000
# 3/3 - 1s - loss: 0.7248 - acc: 0.4667 - auc_26: 0.5533 - val_loss: 0.6948 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 86/1000
# 3/3 - 1s - loss: 0.6880 - acc: 0.5000 - auc_26: 0.5972 - val_loss: 0.6936 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 87/1000
# 3/3 - 1s - loss: 0.6824 - acc: 0.5000 - auc_26: 0.5944 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 88/1000
# 3/3 - 1s - loss: 0.6877 - acc: 0.5000 - auc_26: 0.5300 - val_loss: 0.6936 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 89/1000
# 3/3 - 1s - loss: 0.6540 - acc: 0.6000 - auc_26: 0.6394 - val_loss: 0.6954 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 90/1000
# 3/3 - 1s - loss: 0.6640 - acc: 0.6167 - auc_26: 0.6278 - val_loss: 0.6996 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 91/1000
# 3/3 - 1s - loss: 0.6722 - acc: 0.6000 - auc_26: 0.5800 - val_loss: 0.7062 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 92/1000
# 3/3 - 1s - loss: 0.6724 - acc: 0.6167 - auc_26: 0.6250 - val_loss: 0.7176 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 93/1000
# 3/3 - 1s - loss: 0.6759 - acc: 0.6167 - auc_26: 0.5878 - val_loss: 0.7395 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 94/1000
# 3/3 - 1s - loss: 0.6571 - acc: 0.6167 - auc_26: 0.5839 - val_loss: 0.7778 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 95/1000
# 3/3 - 1s - loss: 0.6553 - acc: 0.6167 - auc_26: 0.5772 - val_loss: 0.8389 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 96/1000
# 3/3 - 1s - loss: 0.6326 - acc: 0.6500 - auc_26: 0.6617 - val_loss: 0.9187 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 97/1000
# 3/3 - 1s - loss: 0.6703 - acc: 0.5833 - auc_26: 0.6156 - val_loss: 0.9692 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 98/1000
# 3/3 - 1s - loss: 0.7084 - acc: 0.5667 - auc_26: 0.5561 - val_loss: 0.9282 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 99/1000
# 3/3 - 1s - loss: 0.6569 - acc: 0.6000 - auc_26: 0.6594 - val_loss: 0.8702 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 100/1000
# 3/3 - 1s - loss: 0.6910 - acc: 0.5833 - auc_26: 0.6033 - val_loss: 0.8036 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 101/1000
# 3/3 - 1s - loss: 0.6917 - acc: 0.5333 - auc_26: 0.5517 - val_loss: 0.7360 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 102/1000
# 3/3 - 1s - loss: 0.6576 - acc: 0.5500 - auc_26: 0.6167 - val_loss: 0.7146 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 103/1000
# 3/3 - 1s - loss: 0.6719 - acc: 0.4833 - auc_26: 0.5900 - val_loss: 0.6995 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 104/1000
# 3/3 - 1s - loss: 0.6763 - acc: 0.5167 - auc_26: 0.5461 - val_loss: 0.6934 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 105/1000
# 3/3 - 1s - loss: 0.6631 - acc: 0.6000 - auc_26: 0.5956 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 106/1000
# 3/3 - 1s - loss: 0.6845 - acc: 0.5833 - auc_26: 0.6239 - val_loss: 0.6973 - val_acc: 0.5000 - val_auc_26: 0.5500
# Epoch 107/1000
# 3/3 - 1s - loss: 0.6648 - acc: 0.5667 - auc_26: 0.5306 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 108/1000
# 3/3 - 1s - loss: 0.6595 - acc: 0.6333 - auc_26: 0.6350 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 109/1000
# 3/3 - 1s - loss: 0.7027 - acc: 0.5667 - auc_26: 0.5767 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 110/1000
# 3/3 - 1s - loss: 0.6898 - acc: 0.5833 - auc_26: 0.5944 - val_loss: 0.6932 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 111/1000
# 3/3 - 1s - loss: 0.6847 - acc: 0.5833 - auc_26: 0.5456 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 112/1000
# 3/3 - 1s - loss: 0.6775 - acc: 0.5833 - auc_26: 0.6428 - val_loss: 0.6933 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 113/1000
# 3/3 - 1s - loss: 0.6574 - acc: 0.6333 - auc_26: 0.6600 - val_loss: 0.6934 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 114/1000
# 3/3 - 1s - loss: 0.6619 - acc: 0.6000 - auc_26: 0.6483 - val_loss: 0.6935 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 115/1000
# 3/3 - 1s - loss: 0.6566 - acc: 0.5833 - auc_26: 0.6311 - val_loss: 0.6935 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 116/1000
# 3/3 - 1s - loss: 0.6395 - acc: 0.6500 - auc_26: 0.6172 - val_loss: 0.6937 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 117/1000
# 3/3 - 1s - loss: 0.6606 - acc: 0.6333 - auc_26: 0.6428 - val_loss: 0.6939 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 118/1000
# 3/3 - 1s - loss: 0.6524 - acc: 0.6833 - auc_26: 0.6128 - val_loss: 0.6942 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 119/1000
# 3/3 - 1s - loss: 0.6346 - acc: 0.6667 - auc_26: 0.6478 - val_loss: 0.6944 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 120/1000
# 3/3 - 1s - loss: 0.6231 - acc: 0.7167 - auc_26: 0.6606 - val_loss: 0.6951 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 121/1000
# 3/3 - 1s - loss: 0.6016 - acc: 0.7167 - auc_26: 0.6861 - val_loss: 0.6966 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 122/1000
# 3/3 - 1s - loss: 0.5804 - acc: 0.7333 - auc_26: 0.7544 - val_loss: 0.6971 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 123/1000
# 3/3 - 1s - loss: 0.6061 - acc: 0.7333 - auc_26: 0.6800 - val_loss: 0.6940 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 124/1000
# 3/3 - 1s - loss: 0.6181 - acc: 0.6833 - auc_26: 0.6678 - val_loss: 0.6934 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 125/1000
# 3/3 - 1s - loss: 0.5757 - acc: 0.7167 - auc_26: 0.7211 - val_loss: 0.6935 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 126/1000
# 3/3 - 1s - loss: 0.6099 - acc: 0.6833 - auc_26: 0.6628 - val_loss: 0.6989 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 127/1000
# 3/3 - 1s - loss: 0.6745 - acc: 0.6167 - auc_26: 0.5750 - val_loss: 0.7057 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 128/1000
# 3/3 - 1s - loss: 0.5832 - acc: 0.7333 - auc_26: 0.7144 - val_loss: 0.7074 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 129/1000
# 3/3 - 1s - loss: 0.6585 - acc: 0.6000 - auc_26: 0.5683 - val_loss: 0.7018 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 130/1000
# 3/3 - 1s - loss: 0.6438 - acc: 0.6500 - auc_26: 0.6583 - val_loss: 0.7024 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 131/1000
# 3/3 - 1s - loss: 0.6210 - acc: 0.6667 - auc_26: 0.6461 - val_loss: 0.7070 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 132/1000
# 3/3 - 1s - loss: 0.6182 - acc: 0.6667 - auc_26: 0.6661 - val_loss: 0.7093 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 133/1000
# 3/3 - 1s - loss: 0.5991 - acc: 0.6833 - auc_26: 0.6850 - val_loss: 0.7177 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 134/1000
# 3/3 - 1s - loss: 0.5810 - acc: 0.7000 - auc_26: 0.6689 - val_loss: 0.7269 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 135/1000
# 3/3 - 1s - loss: 0.5884 - acc: 0.6833 - auc_26: 0.7033 - val_loss: 0.7325 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 136/1000
# 3/3 - 1s - loss: 0.5797 - acc: 0.7000 - auc_26: 0.6856 - val_loss: 0.7399 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 137/1000
# 3/3 - 1s - loss: 0.5551 - acc: 0.7167 - auc_26: 0.6978 - val_loss: 0.7427 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 138/1000
# 3/3 - 1s - loss: 0.5795 - acc: 0.7000 - auc_26: 0.6344 - val_loss: 0.7412 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 139/1000
# 3/3 - 1s - loss: 0.6162 - acc: 0.6667 - auc_26: 0.6783 - val_loss: 0.7342 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 140/1000
# 3/3 - 1s - loss: 0.6039 - acc: 0.6833 - auc_26: 0.6911 - val_loss: 0.7303 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 141/1000
# 3/3 - 1s - loss: 0.6304 - acc: 0.6167 - auc_26: 0.6383 - val_loss: 0.7225 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 142/1000
# 3/3 - 1s - loss: 0.6172 - acc: 0.6500 - auc_26: 0.6044 - val_loss: 0.7181 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 143/1000
# 3/3 - 1s - loss: 0.7004 - acc: 0.6000 - auc_26: 0.6200 - val_loss: 0.7158 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 144/1000
# 3/3 - 1s - loss: 0.6490 - acc: 0.6167 - auc_26: 0.6367 - val_loss: 0.7154 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 145/1000
# 3/3 - 1s - loss: 0.6818 - acc: 0.5167 - auc_26: 0.5928 - val_loss: 0.7143 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 146/1000
# 3/3 - 1s - loss: 0.6514 - acc: 0.5333 - auc_26: 0.6322 - val_loss: 0.7097 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 147/1000
# 3/3 - 1s - loss: 0.6335 - acc: 0.5000 - auc_26: 0.6294 - val_loss: 0.7062 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 148/1000
# 3/3 - 1s - loss: 0.6547 - acc: 0.5333 - auc_26: 0.6361 - val_loss: 0.7040 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 149/1000
# 3/3 - 1s - loss: 0.6492 - acc: 0.6167 - auc_26: 0.6394 - val_loss: 0.7042 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 150/1000
# 3/3 - 1s - loss: 0.6572 - acc: 0.6167 - auc_26: 0.5778 - val_loss: 0.7038 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 151/1000
# 3/3 - 1s - loss: 0.6565 - acc: 0.6167 - auc_26: 0.5806 - val_loss: 0.7034 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 152/1000
# 3/3 - 1s - loss: 0.6553 - acc: 0.6167 - auc_26: 0.6050 - val_loss: 0.7021 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 153/1000
# 3/3 - 1s - loss: 0.6386 - acc: 0.6333 - auc_26: 0.6183 - val_loss: 0.7012 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 154/1000
# 3/3 - 1s - loss: 0.6650 - acc: 0.5833 - auc_26: 0.5667 - val_loss: 0.7002 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 155/1000
# 3/3 - 1s - loss: 0.6546 - acc: 0.6000 - auc_26: 0.6311 - val_loss: 0.7010 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 156/1000
# 3/3 - 1s - loss: 0.6397 - acc: 0.6333 - auc_26: 0.6433 - val_loss: 0.7016 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 157/1000
# 3/3 - 1s - loss: 0.6306 - acc: 0.6333 - auc_26: 0.6733 - val_loss: 0.7039 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 158/1000
# 3/3 - 1s - loss: 0.6309 - acc: 0.6333 - auc_26: 0.6178 - val_loss: 0.7100 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 159/1000
# 3/3 - 1s - loss: 0.6300 - acc: 0.6333 - auc_26: 0.6744 - val_loss: 0.7146 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 160/1000
# 3/3 - 1s - loss: 0.6194 - acc: 0.6333 - auc_26: 0.6744 - val_loss: 0.7224 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 161/1000
# 3/3 - 1s - loss: 0.6402 - acc: 0.6167 - auc_26: 0.6328 - val_loss: 0.7297 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 162/1000
# 3/3 - 1s - loss: 0.6226 - acc: 0.6500 - auc_26: 0.6600 - val_loss: 0.7320 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 163/1000
# 3/3 - 1s - loss: 0.6700 - acc: 0.6000 - auc_26: 0.5794 - val_loss: 0.7283 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 164/1000
# 3/3 - 1s - loss: 0.6609 - acc: 0.6000 - auc_26: 0.6272 - val_loss: 0.7256 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 165/1000
# 3/3 - 1s - loss: 0.6007 - acc: 0.7333 - auc_26: 0.7044 - val_loss: 0.7249 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 166/1000
# 3/3 - 1s - loss: 0.6555 - acc: 0.6500 - auc_26: 0.6450 - val_loss: 0.7261 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 167/1000
# 3/3 - 1s - loss: 0.6280 - acc: 0.6333 - auc_26: 0.6778 - val_loss: 0.7276 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 168/1000
# 3/3 - 1s - loss: 0.6175 - acc: 0.7000 - auc_26: 0.6933 - val_loss: 0.7279 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 169/1000
# 3/3 - 1s - loss: 0.6486 - acc: 0.6333 - auc_26: 0.5667 - val_loss: 0.7246 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 170/1000
# 3/3 - 1s - loss: 0.6347 - acc: 0.6667 - auc_26: 0.6500 - val_loss: 0.7245 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 171/1000
# 3/3 - 1s - loss: 0.6123 - acc: 0.6833 - auc_26: 0.6594 - val_loss: 0.7280 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 172/1000
# 3/3 - 1s - loss: 0.6251 - acc: 0.6667 - auc_26: 0.6233 - val_loss: 0.7267 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 173/1000
# 3/3 - 1s - loss: 0.6599 - acc: 0.6333 - auc_26: 0.5461 - val_loss: 0.7226 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 174/1000
# 3/3 - 1s - loss: 0.6723 - acc: 0.6000 - auc_26: 0.6756 - val_loss: 0.7201 - val_acc: 0.5000 - val_auc_26: 0.5000
# Epoch 175/1000
# 3/3 - 1s - loss: 0.6394 - acc: 0.6333 - auc_26: 0.5878 - val_loss: 0.7151 - val_acc: 0.5000 - val_auc_26: 0.5000
